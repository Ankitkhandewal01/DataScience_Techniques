# %% [markdown]
# # Practice of some concept of pandas with creating raw data and titanic dataset

# %%
import pandas as pd

# %% [markdown]
# # Raw data

# %%
data={'Name':['john','Ajay','abhi'],
     'Age':[20,40,35],
     'City':['New York','Paris','London']}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#    Name  Age      City
# 0  john   20  New York
# 1  Ajay   40     Paris
# 2  abhi   35    London

# %%
df
# Out:
#    Name  Age      City
# 0  john   20  New York
# 1  Ajay   40     Paris
# 2  abhi   35    London

# %%
row =df.loc[0]

# %%
row
# Out:
# Name        john
# Age           20
# City    New York
# Name: 0, dtype: object

# %% [markdown]
# # loc AND iloc

# %%
row =df.loc[1:3]

# %%
row
# Out:
#    Name  Age    City
# 1  Ajay   40   Paris
# 2  abhi   35  London

# %%
x=df.iloc[:,1:3]

# %%
x
# Out:
#    Age      City
# 0   20  New York
# 1   40     Paris
# 2   35    London

# %%
q=df.loc[df['Age']>20]

# %%
q
# Out:
#    Name  Age    City
# 1  Ajay   40   Paris
# 2  abhi   35  London

# %%
r=df[df['Age']>20]

# %%
r
# Out:
#    Name  Age    City
# 1  Ajay   40   Paris
# 2  abhi   35  London

# %%
x=df.iloc[1:3,0:2]

# %%
x
# Out:
#    Name  Age
# 1  Ajay   40
# 2  abhi   35

# %% [markdown]
# # Adding new columns

# %%
df['Salary']=[50000,30000,70000]

# %%
df
# Out:
#    Name  Age      City  Salary
# 0  john   20  New York   50000
# 1  Ajay   40     Paris   30000
# 2  abhi   35    London   70000

# %%
data1={'Name':['john','Ajay','abhi','Ajay','john'],
     'Age':[20,40,35,48,50],
     'City':['New York','Paris','London','New York','Paris']}

# %%
df1=pd.DataFrame(data1)

# %%
df1['Salary']=[50000,30000,70000,32233,22332]

# %%
df1
# Out:
#    Name  Age      City  Salary
# 0  john   20  New York   50000
# 1  Ajay   40     Paris   30000
# 2  abhi   35    London   70000
# 3  Ajay   48  New York   32233
# 4  john   50     Paris   22332

# %% [markdown]
# # Groupby function

# %%
group=df1.groupby('Name').mean()['Salary']

# %%
group
# Out:
# Name
# Ajay    31116.5
# abhi    70000.0
# john    36166.0
# Name: Salary, dtype: float64

# %%
group1=df1.groupby('Name').sum()['Salary']

# %%
group1
# Out:
# Name
# Ajay    62233
# abhi    70000
# john    72332
# Name: Salary, dtype: int64

# %%
r=df1[df1['Name']=='John']

# %%
data2={'Name':['john','Ajay','abhi','Ajay','john'],
      'last_name':['q','q','e','w','y']}

# %%
df2=pd.DataFrame(data2)

# %%
df2
# Out:
#    Name last_name
# 0  john         q
# 1  Ajay         q
# 2  abhi         e
# 3  Ajay         w
# 4  john         y

# %%
df2['Full Name']=df2['Name']+" "+df2['last_name']

# %%
df2
# Out:
#    Name last_name Full Name
# 0  john         q    john q
# 1  Ajay         q    Ajay q
# 2  abhi         e    abhi e
# 3  Ajay         w    Ajay w
# 4  john         y    john y

# %%
data1={'Name':['john','Ajay','abhi','Ajay','john'],
     'Age':[20,40,35,48,50],
     'City':['New York','Paris','London','New York','Paris']}
data2={'Name':['john','Ajay','abhi','Ajay','john'],
      'last_name':['q','q','e','w','y']}

# %%
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)

# %%
df1
# Out:
#    Name  Age      City
# 0  john   20  New York
# 1  Ajay   40     Paris
# 2  abhi   35    London
# 3  Ajay   48  New York
# 4  john   50     Paris

# %%
df2
# Out:
#    Name last_name
# 0  john         q
# 1  Ajay         q
# 2  abhi         e
# 3  Ajay         w
# 4  john         y

# %% [markdown]
# # Concat

# %%
c_c=pd.concat([df1,df2],axis=0,ignore_index=True)

# %%
c_c.reset_index()
# Out:
#    index  Name   Age      City last_name
# 0      0  john  20.0  New York       NaN
# 1      1  Ajay  40.0     Paris       NaN
# 2      2  abhi  35.0    London       NaN
# 3      3  Ajay  48.0  New York       NaN
# 4      4  john  50.0     Paris       NaN
# 5      5  john   NaN       NaN         q
# 6      6  Ajay   NaN       NaN         q
# 7      7  abhi   NaN       NaN         e
# 8      8  Ajay   NaN       NaN         w
# 9      9  john   NaN       NaN         y

# %%
c_c
# Out:
#    Name   Age      City last_name
# 0  john  20.0  New York       NaN
# 1  Ajay  40.0     Paris       NaN
# 2  abhi  35.0    London       NaN
# 3  Ajay  48.0  New York       NaN
# 4  john  50.0     Paris       NaN
# 5  john   NaN       NaN         q
# 6  Ajay   NaN       NaN         q
# 7  abhi   NaN       NaN         e
# 8  Ajay   NaN       NaN         w
# 9  john   NaN       NaN         y

# %%
c_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       10 non-null     object
#  1   Age        5 non-null      float64
#  2   City       5 non-null      object
#  3   last_name  5 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 448.0+ bytes

# %%
c_c.shape
# Out:
# (10, 4)

# %%
c_c.isnull().value_counts()
# Out:
# Name   Age    City   last_name
# False  False  False  True         5
#        True   True   False        5
# dtype: int64

# %%
c_c.isnull()
# Out:
#     Name    Age   City  last_name
# 0  False  False  False       True
# 1  False  False  False       True
# 2  False  False  False       True
# 3  False  False  False       True
# 4  False  False  False       True
# 5  False   True   True      False
# 6  False   True   True      False
# 7  False   True   True      False
# 8  False   True   True      False
# 9  False   True   True      False

# %%
c_c['Age'].value_counts()
# Out:
# 48.0    1
# 20.0    1
# 50.0    1
# 40.0    1
# 35.0    1
# Name: Age, dtype: int64

# %%
c_c["Age"].sum()
# Out:
# 193.0

# %%
c_c["Age"].mean()
# Out:
# 38.6

# %%
c_c["Age"]=c_c["Age"].fillna(0)

# %%
c_c
# Out:
#    Name   Age      City last_name
# 0  john  20.0  New York       NaN
# 1  Ajay  40.0     Paris       NaN
# 2  abhi  35.0    London       NaN
# 3  Ajay  48.0  New York       NaN
# 4  john  50.0     Paris       NaN
# 5  john   0.0       NaN         q
# 6  Ajay   0.0       NaN         q
# 7  abhi   0.0       NaN         e
# 8  Ajay   0.0       NaN         w
# 9  john   0.0       NaN         y

# %%
c_c.fillna(0)
# Out:
#    Name   Age      City last_name
# 0  john  20.0  New York         0
# 1  Ajay  40.0     Paris         0
# 2  abhi  35.0    London         0
# 3  Ajay  48.0  New York         0
# 4  john  50.0     Paris         0
# 5  john   0.0         0         q
# 6  Ajay   0.0         0         q
# 7  abhi   0.0         0         e
# 8  Ajay   0.0         0         w
# 9  john   0.0         0         y

# %%
c=c_c.drop("City",axis=1)

# %%
c
# Out:
#    Name   Age last_name
# 0  john  20.0       NaN
# 1  Ajay  40.0       NaN
# 2  abhi  35.0       NaN
# 3  Ajay  48.0       NaN
# 4  john  50.0       NaN
# 5  john   0.0         q
# 6  Ajay   0.0         q
# 7  abhi   0.0         e
# 8  Ajay   0.0         w
# 9  john   0.0         y

# %%
c_c.describe()
# Out:
#              Age
# count  10.000000
# mean   19.300000
# std    21.868547
# min     0.000000
# 25%     0.000000
# 50%    10.000000
# 75%    38.750000
# max    50.000000

# %% [markdown]
# # Series

# %%
y=pd.Series(["ndn",'dsd','dsd','dd'],name='yes')

# %% [markdown]
# # Loading Train dataset

# %%
df=pd.read_csv("train.csv")

# %%
df
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    MLB Cincinnati Reds T Shirt Size XL                  3
# 1               1       Razer BlackWidow Chroma Keyboard                  3
# 2               2                         AVA-VIV Blouse                  1
# 3               3                  Leather Horse Statues                  1
# 4               4                   24K GOLD plated rose                  1
# ...           ...                                    ...                ...
# 1482530   1482530             Free People Inspired Dress                  2
# 1482531   1482531          Little mermaid handmade dress                  2
# 1482532   1482532  21 day fix containers and eating plan                  2
# 1482533   1482533                 World markets lanterns                  3
# 1482534   1482534          Brand new lux de ville wallet                  1
#
# ...

# %%
df.head(40)
# Out:
#     train_id                                      name  item_condition_id  \
# 0          0       MLB Cincinnati Reds T Shirt Size XL                  3
# 1          1          Razer BlackWidow Chroma Keyboard                  3
# 2          2                            AVA-VIV Blouse                  1
# 3          3                     Leather Horse Statues                  1
# 4          4                      24K GOLD plated rose                  1
# 5          5          Bundled items requested for Ruie                  3
# 6          6        Acacia pacific tides santorini top                  3
# 7          7      Girls cheer and tumbling bundle of 7                  3
# 8          8                     Girls Nike Pro shorts                  3
# 9          9    Porcelain clown doll checker pants VTG                  3
# 10        10                           Smashbox primer                  2
# 11        11                    New vs pi k body mists                  1
# ...

# %%
df.isnull()
# Out:
#          train_id   name  item_condition_id  category_name  brand_name  price  \
# 0           False  False              False          False        True  False
# 1           False  False              False          False       False  False
# 2           False  False              False          False       False  False
# 3           False  False              False          False        True  False
# 4           False  False              False          False        True  False
# ...           ...    ...                ...            ...         ...    ...
# 1482530     False  False              False          False       False  False
# 1482531     False  False              False          False       False  False
# 1482532     False  False              False          False        True  False
# 1482533     False  False              False          False        True  False
# 1482534     False  False              False          False        True  False
#
# ...

# %%
df.isnull().value_counts()
# Out:
# train_id  name   item_condition_id  category_name  brand_name  price  shipping  item_description
# False     False  False              False          False       False  False     False               846982
#                                                    True        False  False     False               629222
#                                     True           True        False  False     False                 3457
#                                                    False       False  False     False                 2870
#                                     False          True        False  False     True                     3
#                                                    False       False  False     True                     1
# dtype: int64

# %%
df.tail(10)
df=df.drop(df.iloc[:,0:4],axis=1)
# Out:
#          train_id                                   name  item_condition_id  \
# 1482525   1482525    Red Victoria's Secret bra w sequins                  2
# 1482526   1482526   Harry Potter Shirt! Women M/ Girl XL                  2
# 1482527   1482527  Blk/white ribbed mock neck bodysuit M                  1
# 1482528   1482528    Victoria's Secret Tankini Sz. Large                  2
# 1482529   1482529                          Men's UA [rm]                  2
# 1482530   1482530             Free People Inspired Dress                  2
# 1482531   1482531          Little mermaid handmade dress                  2
# 1482532   1482532  21 day fix containers and eating plan                  2
# 1482533   1482533                 World markets lanterns                  3
# 1482534   1482534          Brand new lux de ville wallet                  1
#
#                                           category_name         brand_name  \
# ...

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482535 entries, 0 to 1482534
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   train_id           1482535 non-null  int64
#  1   name               1482535 non-null  object
#  2   item_condition_id  1482535 non-null  int64
#  3   category_name      1476208 non-null  object
#  4   brand_name         849853 non-null   object
#  5   price              1482535 non-null  float64
#  6   shipping           1482535 non-null  int64
#  7   item_description   1482531 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 90.5+ MB

# %%
df=df.drop(df.iloc[:,0:4],axis=1)

# %%
df
# Out:
#           brand_name  price  shipping  \
# 0                NaN   10.0         1
# 1              Razer   52.0         0
# 2             Target   10.0         1
# 3                NaN   35.0         1
# 4                NaN   44.0         0
# ...              ...    ...       ...
# 1482530  Free People   20.0         1
# 1482531       Disney   14.0         0
# 1482532          NaN   12.0         0
# 1482533          NaN   45.0         1
# 1482534          NaN   22.0         0
#
#                                           item_description
# 0                                       No description yet
# 1        This keyboard is in great condition and works ...
# 2        Adorable top with a hint of lace and a key hol...
# 3        New with tags. Leather horses. Retail for [rm]...
# 4                Complete with certificate of authenticity
# ...                                                    ...
# 1482530  Lace, says size small but fits medium perfectl...
# ...

# %%
df.iloc[:,0:4]
# Out:
#           brand_name  price  shipping  \
# 0                NaN   10.0         1
# 1              Razer   52.0         0
# 2             Target   10.0         1
# 3                NaN   35.0         1
# 4                NaN   44.0         0
# ...              ...    ...       ...
# 1482530  Free People   20.0         1
# 1482531       Disney   14.0         0
# 1482532          NaN   12.0         0
# 1482533          NaN   45.0         1
# 1482534          NaN   22.0         0
#
#                                           item_description
# 0                                       No description yet
# 1        This keyboard is in great condition and works ...
# 2        Adorable top with a hint of lace and a key hol...
# 3        New with tags. Leather horses. Retail for [rm]...
# 4                Complete with certificate of authenticity
# ...                                                    ...
# 1482530  Lace, says size small but fits medium perfectl...
# ...
