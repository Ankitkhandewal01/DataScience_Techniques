# %% [markdown]
# # Implementaion of Feature engineering- StandardScaler, Normalization and its types & graphs for comparison

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Ankit\Desktop\All folders\BrainyBeam tasks/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df["Age"]=df["Age"].fillna(0)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.Age=df.Age.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 80.2+ KB

# %%
df=df.drop(["PassengerId","Cabin","Embarked","Ticket","Parch","Pclass","SibSp"],axis=1)

# %%
df
# Out:
#      Survived                                               Name     Sex  Age  \
# 0           0                            Braund, Mr. Owen Harris    male   22
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 2           1                             Heikkinen, Miss. Laina  female   26
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 4           0                           Allen, Mr. William Henry    male   35
# ..        ...                                                ...     ...  ...
# 886         0                              Montvila, Rev. Juozas    male   27
# 887         1                       Graham, Miss. Margaret Edith  female   19
# 888         0           Johnston, Miss. Catherine Helen "Carrie"  female    0
# 889         1                              Behr, Mr. Karl Howell    male   26
# 890         0                                Dooley, Mr. Patrick    male   32
#
#         Fare
# 0     7.2500
# ...

# %%
df=df.drop(["Name","Sex"],axis=1)

# %%
df
# Out:
#      Survived  Age     Fare
# 0           0   22   7.2500
# 1           1   38  71.2833
# 2           1   26   7.9250
# 3           1   35  53.1000
# 4           0   35   8.0500
# ..        ...  ...      ...
# 886         0   27  13.0000
# 887         1   19  30.0000
# 888         0    0  23.4500
# 889         1   26  30.0000
# 890         0   32   7.7500
#
# [891 rows x 3 columns]

# %% [markdown]
# # Splitting data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop("Survived",axis=1),df["Survived"],test_size=0.3)

# %%
x_train.shape,y_train.shape
# Out:
# ((623, 2), (623,))

# %%
x_train
# Out:
#      Age      Fare
# 422   29    7.8750
# 295    0   27.7208
# 36     0    7.2292
# 44    19    7.8792
# 414   44    7.9250
# ..   ...       ...
# 845   42    7.5500
# 848   28   33.0000
# 659   58  113.2750
# 55     0   35.5000
# 763   36  120.0000
#
# [623 rows x 2 columns]

# %%
x_test
# Out:
#      Age     Fare
# 728   25  26.0000
# 479    2  12.2875
# 63     4  27.9000
# 391   21   7.7958
# 72    21  73.5000
# ..   ...      ...
# 732    0   0.0000
# 107    0   7.7750
# 554   22   7.7750
# 487   58  29.7000
# 576   34  13.0000
#
# [268 rows x 2 columns]

# %%
y_train
# Out:
# 422    0
# 295    0
# 36     1
# 44     1
# 414    1
#       ..
# 845    0
# 848    0
# 659    0
# 55     1
# 763    1
# Name: Survived, Length: 623, dtype: int64

# %% [markdown]
# # StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
df.describe()
# Out:
#          Survived         Age        Fare
# count  891.000000  891.000000  891.000000
# mean     0.383838   23.783389   32.204208
# std      0.486592   17.597344   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    6.000000    7.910400
# 50%      0.000000   24.000000   14.454200
# 75%      1.000000   35.000000   31.000000
# max      1.000000   80.000000  512.329200

# %%
scaler=StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaler=scaler.transform(x_train)
x_test_scaler=scaler.transform(x_test)

# %%
scaler.mean_
# Out:
# array([23.42215088, 31.9071886 ])

# %%
x_train_scaler
# Out:
# array([[ 0.32176368, -0.4898811 ],
#        [-1.35112966, -0.08533691],
#        [-1.35112966, -0.50304533],
#        ...,
#        [ 1.99465701,  1.65863183],
#        [-1.35112966,  0.07323721],
#        [ 0.72556551,  1.79571674]])

# %%
x_test_scaler
# Out:
# array([[ 9.10197679e-02, -1.20414337e-01],
#        [-1.23575770e+00, -3.99935054e-01],
#        [-1.12038575e+00, -8.16840279e-02],
#        [-1.39724140e-01, -4.91495543e-01],
#        [-1.39724140e-01,  8.47843390e-01],
#        [ 7.25565515e-01, -6.50408040e-01],
#        [-1.35112966e+00, -4.92429148e-01],
#        [-3.70468048e-01, -5.05169381e-01],
#        [ 2.64077699e-01, -1.91250034e-01],
#        [-1.35112966e+00, -3.34450256e-01],
#        [-1.35112966e+00,  4.70732486e-01],
#        [-1.35112966e+00, -4.86313836e-01],
#        [ 2.16771494e+00,  8.43120906e-03],
#        [ 3.33337909e-02, -3.85411189e-01],
#        [ 6.67879538e-01,  1.18418555e+00],
#        [ 1.82159908e+00, -4.86313836e-01],
#        [ 9.10197679e-02,  2.43884372e+00],
#        [ 1.24473931e+00,  2.71029630e+00],
#        [ 3.79449653e-01,  1.25553085e+00],
#        [-1.35112966e+00, -1.09202932e-01],
#        [ 3.21763676e-01, -8.53369076e-02],
#        [-3.70468048e-01, -3.55684657e-01],
# ...

# %%
x_train_scaler=pd.DataFrame(x_train_scaler,columns=x_train.columns)

# %%
x_train_scaler
# Out:
#           Age      Fare
# 0    0.321764 -0.489881
# 1   -1.351130 -0.085337
# 2   -1.351130 -0.503045
# 3   -0.255096 -0.489795
# 4    1.187053 -0.488862
# ..        ...       ...
# 618  1.071681 -0.496506
# 619  0.264078  0.022276
# 620  1.994657  1.658632
# 621 -1.351130  0.073237
# 622  0.725566  1.795717
#
# [623 rows x 2 columns]

# %%
x_test_scaler=pd.DataFrame(x_test_scaler,columns=x_test.columns)

# %%
x_test_scaler
# Out:
#           Age      Fare
# 0    0.091020 -0.120414
# 1   -1.235758 -0.399935
# 2   -1.120386 -0.081684
# 3   -0.139724 -0.491496
# 4   -0.139724  0.847843
# ..        ...       ...
# 263 -1.351130 -0.650408
# 264 -1.351130 -0.491920
# 265 -0.082038 -0.491920
# 266  1.994657 -0.044992
# 267  0.610194 -0.385411
#
# [268 rows x 2 columns]

# %%
x_test_scaler.describe()
# Out:
#               Age        Fare
# count  268.000000  268.000000
# mean     0.069280    0.020129
# std      1.047947    1.042468
# min     -1.351130   -0.650408
# 25%     -0.904063   -0.486314
# 50%      0.062177   -0.355768
# 75%      0.725566   -0.017091
# max      2.744575    9.793102

# %%
x_train_scaler.describe()
# Out:
#                 Age          Fare
# count  6.230000e+02  6.230000e+02
# mean   3.172066e-17 -2.780013e-17
# std    1.000804e+00  1.000804e+00
# min   -1.351130e+00 -6.504080e-01
# 25%   -1.033857e+00 -4.894571e-01
# 50%    3.333379e-02 -3.556847e-01
# 75%    6.678795e-01 -2.159293e-02
# max    3.263749e+00  9.793102e+00

# %%
import numpy as np

# %%
np.round(x_train_scaler.describe(),1)
# Out:
#          Age   Fare
# count  623.0  623.0
# mean     0.0   -0.0
# std      1.0    1.0
# min     -1.4   -0.7
# 25%     -1.0   -0.5
# 50%      0.0   -0.4
# 75%      0.7   -0.0
# max      3.3    9.8

# %% [markdown]
# # Graphs for StandardScaler

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_train["Age"],x_train["Fare"])
a1.set_title("Befor scaling")
a2.scatter(x_train_scaler["Age"],x_train_scaler["Fare"])
a2.set_title("After scaling")
plt.show()

# %% [markdown]
# # Normalization

# %% [markdown]
# # MinMax-scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(x_train,y_train)
# Out:
# MinMaxScaler()

# %%
x_train_scaler=scaler.transform(x_train)
x_test_scaler=scaler.transform(x_test)

# %%
x_train_scaler
# Out:
# array([[0.3625    , 0.01537098],
#        [0.        , 0.0541074 ],
#        [0.        , 0.01411046],
#        ...,
#        [0.725     , 0.22109808],
#        [0.        , 0.06929139],
#        [0.45      , 0.2342244 ]])

# %%
x_test_scaler
# Out:
# array([[0.3125    , 0.05074862],
#        [0.025     , 0.0239836 ],
#        [0.05      , 0.05445717],
#        [0.2625    , 0.01521639],
#        [0.2625    , 0.14346245],
#        [0.45      , 0.        ],
#        [0.        , 0.01512699],
#        [0.2125    , 0.01390707],
#        [0.35      , 0.04396587],
#        [0.        , 0.03025399],
#        [0.        , 0.10735285],
#        [0.        , 0.01571255],
#        [0.7625    , 0.063086  ],
#        [0.3       , 0.02537431],
#        [0.4375    , 0.1756683 ],
#        [0.6875    , 0.01571255],
#        [0.3125    , 0.2958059 ],
#        [0.5625    , 0.32179837],
#        [0.375     , 0.18249985],
#        [0.        , 0.05182215],
#        [0.3625    , 0.0541074 ],
#        [0.2125    , 0.02822072],
#        [0.625     , 0.02049464],
#        [0.175     , 0.2342244 ],
#        [0.3875    , 0.07222739],
#        [0.        , 0.01415106],
#        [0.        , 0.02947324],
#        [0.        , 0.01376068],
# ...

# %%
x_train_scaler=pd.DataFrame(x_train_scaler,columns=x_train.columns)
x_test_scaler=pd.DataFrame(x_test_scaler,columns=x_test.columns)

# %%
x_train_scaler
# Out:
#         Age      Fare
# 0    0.3625  0.015371
# 1    0.0000  0.054107
# 2    0.0000  0.014110
# 3    0.2375  0.015379
# 4    0.5500  0.015469
# ..      ...       ...
# 618  0.5250  0.014737
# 619  0.3500  0.064412
# 620  0.7250  0.221098
# 621  0.0000  0.069291
# 622  0.4500  0.234224
#
# [623 rows x 2 columns]

# %%
x_test_scaler
# Out:
#         Age      Fare
# 0    0.3125  0.050749
# 1    0.0250  0.023984
# 2    0.0500  0.054457
# 3    0.2625  0.015216
# 4    0.2625  0.143462
# ..      ...       ...
# 263  0.0000  0.000000
# 264  0.0000  0.015176
# 265  0.2750  0.015176
# 266  0.7250  0.057971
# 267  0.4250  0.025374
#
# [268 rows x 2 columns]

# %%
np.round(x_train_scaler.describe(),1)
# Out:
#          Age   Fare
# count  623.0  623.0
# mean     0.3    0.1
# std      0.2    0.1
# min      0.0    0.0
# 25%      0.1    0.0
# 50%      0.3    0.0
# 75%      0.4    0.1
# max      1.0    1.0

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_train["Age"],x_train["Fare"])
a1.set_title("Befor scaling")
a2.scatter(x_train_scaler["Age"],x_train_scaler["Fare"])
a2.set_title("After scaling")
plt.show()

# %% [markdown]
# # MaxAbsScaler

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
scaler=MaxAbsScaler()

# %%
scaler.fit(x_train,y_train)
# Out:
# MaxAbsScaler()

# %%
x_train_scaler=scaler.transform(x_train)
x_test_scaler=scaler.transform(x_test)

# %%
x_train_scaler
# Out:
# array([[0.3625    , 0.01537098],
#        [0.        , 0.0541074 ],
#        [0.        , 0.01411046],
#        ...,
#        [0.725     , 0.22109808],
#        [0.        , 0.06929139],
#        [0.45      , 0.2342244 ]])

# %%
x_train_scaler=pd.DataFrame(x_train_scaler,columns=x_train.columns)
x_test_scaler=pd.DataFrame(x_test_scaler,columns=x_test.columns)

# %%
np.round(x_train_scaler.describe(),1)
# Out:
#          Age   Fare
# count  623.0  623.0
# mean     0.3    0.1
# std      0.2    0.1
# min      0.0    0.0
# 25%      0.1    0.0
# 50%      0.3    0.0
# 75%      0.4    0.1
# max      1.0    1.0

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_train["Age"],x_train["Fare"])
a1.set_title("Befor scaling")
a2.scatter(x_train_scaler["Age"],x_train_scaler["Fare"])
a2.set_title("After scaling")
plt.show()

# %% [markdown]
# # RobustScaler

# %%
from sklearn.preprocessing import RobustScaler
r=RobustScaler()
x_train_scaler=r.fit_transform(x_train)
x_test_scaler=r.transform(x_test)
x_train_scaler=pd.DataFrame(x_train_scaler,columns=x_train.columns)
x_test_scaler=pd.DataFrame(x_test_scaler,columns=x_test.columns)
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_train["Age"],x_train["Fare"])
a1.set_title("Befor scaling")
a2.scatter(x_train_scaler["Age"],x_train_scaler["Fare"])
a2.set_title("After scaling")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_data = pd.read_csv(r"C:\Users\Ankit\Desktop\All folders\BrainyBeam tasks/train.csv")
# Calculate the correlation matrix
correlation_matrix = titanic_data.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix - Titanic Dataset')

# Display the plot
plt.show()

# %%
correlation_matrix
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
c=titanic_data.Sex.unique()

# %%
titanic_data['Age'].fillna(0)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# # pandas.pivot(index, columns, values)

# %%
pivoted_data = pd.pivot_table(titanic_data, index='Survived', columns='Sex', values='Age')

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(pivoted_data, annot=True, cmap='coolwarm')
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

# Load the Iris dataset
X, y = load_iris(return_X_y=True)

# Create two logistic regression models with different values of C
model_regularized = LogisticRegression(C=0.1)
model_no_regularization = LogisticRegression(C=10)

# Fit the models to the data
model_regularized.fit(X, y)
model_no_regularization.fit(X, y)

# Print the coefficients
print("Regularized Model Coefficients:", model_regularized.coef_)
print("No Regularization Model Coefficients:", model_no_regularization.coef_)
# Out:
# Regularized Model Coefficients: [[-0.30245855  0.34626876 -1.1811841  -0.48002144]
#  [ 0.0709291  -0.33152656  0.07289077 -0.23053665]
#  [ 0.23152945 -0.0147422   1.10829333  0.71055808]]
# No Regularization Model Coefficients: [[-0.44341092  2.10844416 -4.28976305 -1.95355035]
#  [ 1.07252358 -0.08496313 -0.46682262 -2.34006155]
#  [-0.62911266 -2.02348103  4.75658567  4.2936119 ]]
# C:\Users\Ankit\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
