# %% [markdown]
# # Implementation of Linear Regression with RFE only using Sales dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import  LinearRegression

# %%
df=pd.read_csv("Sales.csv")

# %%
df
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
df.isnull().sum()
# Out:
# Region              0
# Country             0
# Item_Type           0
# Sales_Channel       0
# Order_Priority      0
# Ship_Date           0
# Unit_Cost           0
# Total_Revenue       0
# Total_Profit        0
# Unnamed: 9        100
# Unnamed: 10       100
# dtype: int64

# %%
df.drop(["Unnamed: 9",'Unnamed: 10'],axis=1,inplace=True)

# %%
df
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#         Unit_Cost  Total_Revenue  Total_Profit
# count  100.000000   1.000000e+02  1.000000e+02
# mean   191.048000   1.373488e+06  4.416820e+05
# std    188.208181   1.460029e+06  4.385379e+05
# min      6.920000   4.870260e+03  1.258020e+03
# 25%     35.840000   2.687212e+05  1.214436e+05
# 50%    107.275000   7.523144e+05  2.907680e+05
# 75%    263.330000   2.212045e+06  6.358288e+05
# max    524.960000   5.997055e+06  1.719922e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item_Type       100 non-null    object
#  3   Sales_Channel   100 non-null    object
#  4   Order_Priority  100 non-null    object
#  5   Ship_Date       100 non-null    object
#  6   Unit_Cost       100 non-null    float64
#  7   Total_Revenue   100 non-null    float64
#  8   Total_Profit    100 non-null    float64
# dtypes: float64(3), object(6)
# memory usage: 7.2+ KB

# %%
df["Ship_Date"]=pd.to_datetime(df["Ship_Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item_Type       100 non-null    object
#  3   Sales_Channel   100 non-null    object
#  4   Order_Priority  100 non-null    object
#  5   Ship_Date       100 non-null    datetime64[ns]
#  6   Unit_Cost       100 non-null    float64
#  7   Total_Revenue   100 non-null    float64
#  8   Total_Profit    100 non-null    float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 7.2+ KB

# %%
df.Order_Priority.value_counts()
# Out:
# H    30
# L    27
# C    22
# M    21
# Name: Order_Priority, dtype: int64

# %%
import seaborn as sns

# %%
correlation=df.corr()

# %%
correlation
# Out:
#                Unit_Cost  Total_Revenue  Total_Profit
# Unit_Cost       1.000000       0.715623      0.467214
# Total_Revenue   0.715623       1.000000      0.897327
# Total_Profit    0.467214       0.897327      1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocession

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Label=LabelEncoder()

# %%
df["Sales_Channel"]=Label.fit_transform(df["Sales_Channel"])

# %%
df.drop(["Region"],axis=1,inplace=True)

# %%
df
# Out:
#                   Country        Item_Type  Sales_Channel Order_Priority  \
# 0                  Tuvalu        Baby Food              0              H
# 1                 Grenada           Cereal              1              C
# 2                  Russia  Office Supplies              0              L
# 3   Sao Tome and Principe           Fruits              1              C
# 4                  Rwanda  Office Supplies              0              L
# ..                    ...              ...            ...            ...
# 95                   Mali          Clothes              1              M
# 96               Malaysia           Fruits              0              L
# 97           Sierra Leone       Vegetables              0              C
# 98                 Mexico    Personal Care              0              M
# 99             Mozambique        Household              0              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# ...

# %%
df=pd.get_dummies(df,columns=["Order_Priority"],drop_first=True,sparse=True,dtype=int)

# %%
df
# Out:
#                   Country        Item_Type  Sales_Channel  Ship_Date  \
# 0                  Tuvalu        Baby Food              0 2010-06-27
# 1                 Grenada           Cereal              1 2012-09-15
# 2                  Russia  Office Supplies              0 2014-05-08
# 3   Sao Tome and Principe           Fruits              1 2014-07-05
# 4                  Rwanda  Office Supplies              0 2013-02-06
# ..                    ...              ...            ...        ...
# 95                   Mali          Clothes              1 2011-09-03
# 96               Malaysia           Fruits              0 2011-12-28
# 97           Sierra Leone       Vegetables              0 2016-06-29
# 98                 Mexico    Personal Care              0 2015-08-08
# 99             Mozambique        Household              0 2012-02-15
#
#     Unit_Cost  Total_Revenue  Total_Profit  Order_Priority_H  \
# 0      159.42     2533654.00     951410.50                 1
# ...

# %%
df['Item_Type'].value_counts()
# Out:
# Clothes            13
# Cosmetics          13
# Office Supplies    12
# Fruits             10
# Personal Care      10
# Household           9
# Beverages           8
# Cereal              7
# Baby Food           7
# Vegetables          6
# Snacks              3
# Meat                2
# Name: Item_Type, dtype: int64

# %%
x=df[df['Sales_Channel']==1]

# %%
y=df[df['Sales_Channel']==0]

# %%
plt.bar(df['Sales_Channel'],df['Total_Profit'])
# Out:
# <BarContainer object of 100 artists>

# %%
df
# Out:
#                   Country        Item_Type  Sales_Channel  Ship_Date  \
# 0                  Tuvalu        Baby Food              0 2010-06-27
# 1                 Grenada           Cereal              1 2012-09-15
# 2                  Russia  Office Supplies              0 2014-05-08
# 3   Sao Tome and Principe           Fruits              1 2014-07-05
# 4                  Rwanda  Office Supplies              0 2013-02-06
# ..                    ...              ...            ...        ...
# 95                   Mali          Clothes              1 2011-09-03
# 96               Malaysia           Fruits              0 2011-12-28
# 97           Sierra Leone       Vegetables              0 2016-06-29
# 98                 Mexico    Personal Care              0 2015-08-08
# 99             Mozambique        Household              0 2012-02-15
#
#     Unit_Cost  Total_Revenue  Total_Profit  Order_Priority_H  \
# 0      159.42     2533654.00     951410.50                 1
# ...

# %% [markdown]
# # Splitting data

# %%
x=df.drop(['Country','Item_Type','Total_Profit','Ship_Date'],axis=1)

# %%
y=df.iloc[:,6:7]

# %%
y
# Out:
#     Total_Profit
# 0      951410.50
# 1      248406.36
# 2      224598.75
# 3       19525.82
# 4      639077.50
# ..           ...
# 95      65214.72
# 96      15103.47
# 97      93748.05
# 98     144521.02
# 99     889472.91
#
# [100 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#     Sales_Channel  Unit_Cost  Total_Revenue  Order_Priority_H  \
# 11              0      35.84      455479.04                 1
# 47              1      56.67       22312.29                 0
# 85              0      56.67      524870.06                 0
# 28              0      31.79      243133.80                 0
# 93              1     263.33     3458252.00                 1
# ..            ...        ...            ...               ...
# 60              0     117.11      140287.40                 1
# 71              1       6.92        6279.09                 0
# 14              0      56.67      400558.73                 0
# 92              1     524.96     1316095.41                 0
# 51              1       6.92       89623.98                 0
#
#     Order_Priority_L  Order_Priority_M
# 11                 0                 0
# 47                 0                 1
# 85                 1                 0
# 28                 0                 0
# ...

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# Assuming you have split your dataset into features (X) and target variable (y)
estimator = LinearRegression()
selector = RFE(estimator, n_features_to_select=4)
selector.fit(x_train, y_train)
best_feature_indices = selector.get_support(indices=True)
best_features = x_train.columns[best_feature_indices]
print("Best features for linear regression:", best_features)
# Out:
# Best features for linear regression: Index(['Sales_Channel', 'Order_Priority_H', 'Order_Priority_L',
#        'Order_Priority_M'],
#       dtype='object')
# C:\Users\Ankit\anaconda3\lib\site-packages\sklearn\utils\validation.py:785: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   warnings.warn(
